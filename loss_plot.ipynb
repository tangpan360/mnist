# %%
import joblib

# %%
loss_dict: dict = joblib.load('./loss_path/loss.dict')

# %%
loss_dict
# Out:
# {'train_class_loss_array': array([1.3904216 , 0.3651542 , 0.26607059, 0.21841366, 0.18635873,
#         0.16278641, 0.14552198, 0.13201363, 0.12145094, 0.11297549,
#         0.10555649, 0.099677  , 0.0941506 , 0.08967862, 0.08574514,
#         0.08155789, 0.07887469, 0.07631979, 0.07402467, 0.0710981 ,
#         0.06900703, 0.06698913, 0.06499835, 0.06379765, 0.06194095,
#         0.06012264, 0.05967603, 0.05829136, 0.05691468, 0.05576912,
#         0.05442775, 0.0536062 , 0.05278091, 0.05174053, 0.05120784,
#         0.05020016, 0.04956425, 0.0481092 , 0.04787606, 0.04671259,
#         0.04581227, 0.04543495, 0.04455389, 0.04394068, 0.04361158,
#         0.04275318, 0.04227214, 0.04159932, 0.04114583, 0.04044491,
#         0.03982416, 0.03942341, 0.03878915, 0.03838141, 0.03793966,
#         0.0375653 , 0.03689061, 0.03662639, 0.03590147, 0.0360523 ,
#         0.0354337 , 0.03525341, 0.03440277, 0.03394525, 0.03366955,
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(loss_dict['train_class_loss_array'], color='green', marker='o')
plt.plot(loss_dict['eval_class_loss_array'], color='red')

# %%
plt.plot(loss_dict['train_accuracy'], color='green', marker='o')
plt.plot(loss_dict['eval_accuracy'], color='red', marker='*')
